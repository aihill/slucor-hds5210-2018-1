# %% [markdown]
# _HDS5210 - Programming for Health Data Scientists_
#
# # Week 9 - Data Structures - JSON
#
# JSON is the abbreviation for Javascript Object Notation.  JSON is a very common way that web-based applications communication information to eachother and the native way that web browsers manage dynamic data internally (even though webpage content is written in HTML - a form of XML).
#
# In this part of the lecture, we'll be working on reading / processing / writing JSON.

# %%
# %%bash
# head /data/aco_year1.csv
# Out:
# "ACO Name (LBN or DBA, if applicable) ",States Where Beneficiaries Reside ,Agreement Start Date,Track,Participate in Advance Payment Model ,Total Assigned Beneficiaries,Total Benchmark Expenditures,Total Expenditures,Total Benchmark Expenditures Minus Total Assigned Beneficiary Expenditures,Total Benchmark Expenditures Minus Total Assigned Beneficiary Expenditures as % of Total Benchmark,"Generated Savings/Losses1,2","Earned Shared Savings Payments/Owe Losses3,4",Successfully Reported Quality5,ACO-1,ACO-2,ACO-3,ACO-4,ACO-5,ACO-6,ACO-7,ACO-8^,ACO-9^,ACO-10^,ACO-11,ACO-12,ACO-13,ACO-14,ACO-15,ACO-16,ACO-17,ACO-18,ACO-19,ACO-20,ACO-21,DM Comp-osite,ACO-22,ACO-23,ACO-24,ACO-25,ACO-26,ACO-27^,ACO-28,ACO-29,ACO-30,ACO-31,CAD Comp-osite,ACO-32,ACO-33
# "A.M. Beajow, M.D. Internal Medicine Associates ACO, P.C",Nevada,01/01/2013,Track1 ,No ,5921,$70912015,$67555873,$3356142,4.7%,$3356142,$1644510,Yes,75.6,93.09,92.18,82.91,58.06,76.36,71.33,14.88,0.67,1.14,75,72.5,1.24,25.83,22.4,31.19,64.08,0,39.41,38.12,75.48,17.76,60.28,50,58.18,53.04,28.21,32.94,61.25,13.08,27.36,,37.5,52.31,29.74
# AAMC Collaborative Care Network,Maryland,01/01/2013,Track1 ,No ,10485,$92961659,$96240231,$-3278573,-3.5%,,,Yes,84.67,94.39,93.32,83.13,59.23,71.51,73.72,15.1,1.12,1.8,82.5,97.74,68.86,71.26,66.9,69.21,82.89,57.58,74.94,63.59,63.12,29.25,72.88,59.91,70.05,87.5,65.35,17.22,68.61,74.52,93.33,88.89,67.31,90.31,40.66
# "Accountable Care Clinical Services, PC","Iowa, Pennsylvania, Connecticut, Massachusetts, California",01/01/2013,Track1 ,No ,19637,$211247324,$200721155,$10526169,5%,$10526169,$5157823,Yes,82.78,93.55,92.02,84.84,59.5,76.38,72.12,15.08,1.47,1.31,62.76,46.4,19.15,59.57,57.06,50.65,84.48,13.18,61.69,55.06,58.75,24.17,73.96,54.17,67.5,73.13,81.1,18.75,66.45,55.14,82.72,75,69.78,77.44,77.59
# "Accountable Care Coalition of Caldwell County, LLC",North Carolina,04/01/2012,Track1 ,No ,5915,$70881173,$71400316,$-519143,-0.7%,,,Yes,80.56,92.18,91.69,89.35,51.92,74.85,69.99,14.26,0.81,0.8,47.37,59.34,9.32,45.02,35.92,41.97,59.23,3.41,51.71,63.66,77.14,2.6,57.14,43.9,57.92,13.51,72.54,35.32,50.61,32.11,71.32,75,48.17,54.09,66.31
# "Accountable Care Coalition of Central Georgia, LLC.",Georgia,01/01/2013,Track1 ,No ,10589,$106323535,$107639420,$-1315885,-1.2%,,,Yes,83.09,92.72,92.24,86.74,52.24,67.97,68.83,15.37,1.55,1.39,55.56,24.49,15.1,33.4,21.86,39.72,64.93,5.2,48.25,36.34,81.23,0.79,37.89,23.16,55.79,10.79,73.38,57.11,55.88,20.22,53.01,79.55,28.12,34.84,57.56
# "Accountable Care Coalition of Coastal Georgia, LLC","South Carolina, Georgia",04/01/2012,Track1 ,No ,10475,$146133176,$146775276,$-642100,-0.4%,,,Yes,76.9,92.89,91.88,86.64,55.2,74.24,69.77,14.17,1.02,1.04,90.32,25.4,27.52,48.09,48.53,51.59,84.54,16.01,58.03,68.69,89.69,4.11,64.01,58.21,68.36,13.04,62.84,28.26,71.33,50.48,75.6,80.77,52.66,66.67,50.27
# "Accountable Care Coalition of DeKalb, LLC.",Georgia,01/01/2013,Track2 ,No ,18446,$154953182,$151981618,$2971564,1.9%,,,Yes,84.51,93.94,92.4,84.02,57.15,70.73,72.17,14.75,1.18,1.47,52.38,45.6,10.27,41.74,29.77,48.39,74.42,4.65,49.55,47.72,92.06,1.25,59.25,42.2,62.99,7.07,65.93,35.14,62.69,30.72,64.33,85.86,39.65,47.39,67.08
# "Accountable Care Coalition of Eastern North Carolina, LLC",North Carolina,04/01/2012,Track1 ,No ,10205,$118613931,$126553616,$-7939686,-6.7%,,,Yes,82.16,92.8,91.13,86.06,55.33,75.84,72.11,14.6,0.59,1.03,37.04,52.46,7.12,52.89,37.35,40.54,52.23,3,53.87,52.63,83.96,1.46,56.59,42.44,53.66,9.76,70.73,33.66,57.67,35.29,55.88,61.9,43.65,55.8,50
# "Accountable Care Coalition of Georgia, LLC.",Georgia,01/01/2013,Track1 ,No ,10569,$86425295,$84646537,$1778758,2.1%,,,Yes,73.86,92.98,89.1,84.68,55.67,72.98,70.3,14.96,1.96,1.27,,63.25,16.74,29.66,29.69,46.63,78.05,34.05,39.89,56.26,83.61,3.13,55.53,37.02,58.65,20.67,68.47,33.89,56.59,34.69,71.43,82.14,48.13,56.74,67.47

# %% [markdown]
# ## The json module
#
# https://docs.python.org/3/library/json.html

# %%
import json

# %%
help(json)
# Out:
# Help on package json:
#
# NAME
#     json
#
# MODULE REFERENCE
#     https://docs.python.org/3.5/library/json.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     JSON (JavaScript Object Notation) <http://json.org> is a subset of
#     JavaScript syntax (ECMA-262 3rd edition) used as a lightweight data
#     interchange format.
#
#     :mod:`json` exposes an API familiar to users of the standard library
#     :mod:`marshal` and :mod:`pickle` modules.  It is derived from a
#     version of the externally maintained simplejson library.
#
#     Encoding basic Python object hierarchies::
#
#         >>> import json
#         >>> json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
#         '["foo", {"bar": ["baz", null, 1.0, 2]}]'
#         >>> print(json.dumps("\"foo\bar"))
#         "\"foo\bar"
#         >>> print(json.dumps('\u1234'))
#         "\u1234"
#         >>> print(json.dumps('\\'))
#         "\\"
#         >>> print(json.dumps({"c": 0, "b": 0, "a": 0}, sort_keys=True))
#         {"a": 0, "b": 0, "c": 0}
#         >>> from io import StringIO
#         >>> io = StringIO()
#         >>> json.dump(['streaming API'], io)
#         >>> io.getvalue()
#         '["streaming API"]'
#
#     Compact encoding::
#
#         >>> import json
#         >>> from collections import OrderedDict
#         >>> mydict = OrderedDict([('4', 5), ('6', 7)])
#         >>> json.dumps([1,2,3,mydict], separators=(',', ':'))
#         '[1,2,3,{"4":5,"6":7}]'
#
#     Pretty printing::
#
#         >>> import json
#         >>> print(json.dumps({'4': 5, '6': 7}, sort_keys=True, indent=4))
#         {
#             "4": 5,
#             "6": 7
#         }
#
#     Decoding JSON::
#
#         >>> import json
#         >>> obj = ['foo', {'bar': ['baz', None, 1.0, 2]}]
#         >>> json.loads('["foo", {"bar":["baz", null, 1.0, 2]}]') == obj
#         True
#         >>> json.loads('"\\"foo\\bar"') == '"foo\x08ar'
#         True
#         >>> from io import StringIO
#         >>> io = StringIO('["streaming API"]')
#         >>> json.load(io)[0] == 'streaming API'
#         True
#
#     Specializing JSON object decoding::
#
#         >>> import json
#         >>> def as_complex(dct):
#         ...     if '__complex__' in dct:
#         ...         return complex(dct['real'], dct['imag'])
#         ...     return dct
#         ...
#         >>> json.loads('{"__complex__": true, "real": 1, "imag": 2}',
#         ...     object_hook=as_complex)
#         (1+2j)
#         >>> from decimal import Decimal
#         >>> json.loads('1.1', parse_float=Decimal) == Decimal('1.1')
#         True
#
#     Specializing JSON object encoding::
#
#         >>> import json
#         >>> def encode_complex(obj):
#         ...     if isinstance(obj, complex):
#         ...         return [obj.real, obj.imag]
#         ...     raise TypeError(repr(o) + " is not JSON serializable")
#         ...
#         >>> json.dumps(2 + 1j, default=encode_complex)
#         '[2.0, 1.0]'
#         >>> json.JSONEncoder(default=encode_complex).encode(2 + 1j)
#         '[2.0, 1.0]'
#         >>> ''.join(json.JSONEncoder(default=encode_complex).iterencode(2 + 1j))
#         '[2.0, 1.0]'
#
#
#     Using json.tool from the shell to validate and pretty-print::
#
#         $ echo '{"json":"obj"}' | python -m json.tool
#         {
#             "json": "obj"
#         }
#         $ echo '{ 1.2:3.4}' | python -m json.tool
#         Expecting property name enclosed in double quotes: line 1 column 3 (char 2)
#
# PACKAGE CONTENTS
#     decoder
#     encoder
#     scanner
#     tool
#
# CLASSES
#     builtins.ValueError(builtins.Exception)
#         json.decoder.JSONDecodeError
#     builtins.object
#         json.decoder.JSONDecoder
#         json.encoder.JSONEncoder
#
#     class JSONDecodeError(builtins.ValueError)
#      |  Subclass of ValueError with the following additional properties:
#      |
#      |  msg: The unformatted error message
#      |  doc: The JSON document being parsed
#      |  pos: The start index of doc where parsing failed
#      |  lineno: The line corresponding to pos
#      |  colno: The column corresponding to pos
#      |
#      |  Method resolution order:
#      |      JSONDecodeError
#      |      builtins.ValueError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, msg, doc, pos)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __reduce__(self)
#      |      helper for pickle
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.ValueError:
#      |
#      |  __new__(*args, **kwargs) from builtins.type
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __delattr__(self, name, /)
#      |      Implement delattr(self, name).
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setattr__(self, name, value, /)
#      |      Implement setattr(self, name, value).
#      |
#      |  __setstate__(...)
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class JSONDecoder(builtins.object)
#      |  Simple JSON <http://json.org> decoder
#      |
#      |  Performs the following translations in decoding by default:
#      |
#      |  +---------------+-------------------+
#      |  | JSON          | Python            |
#      |  +===============+===================+
#      |  | object        | dict              |
#      |  +---------------+-------------------+
#      |  | array         | list              |
#      |  +---------------+-------------------+
#      |  | string        | str               |
#      |  +---------------+-------------------+
#      |  | number (int)  | int               |
#      |  +---------------+-------------------+
#      |  | number (real) | float             |
#      |  +---------------+-------------------+
#      |  | true          | True              |
#      |  +---------------+-------------------+
#      |  | false         | False             |
#      |  +---------------+-------------------+
#      |  | null          | None              |
#      |  +---------------+-------------------+
#      |
#      |  It also understands ``NaN``, ``Infinity``, and ``-Infinity`` as
#      |  their corresponding ``float`` values, which is outside the JSON spec.
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, strict=True, object_pairs_hook=None)
#      |      ``object_hook``, if specified, will be called with the result
#      |      of every JSON object decoded and its return value will be used in
#      |      place of the given ``dict``.  This can be used to provide custom
#      |      deserializations (e.g. to support JSON-RPC class hinting).
#      |
#      |      ``object_pairs_hook``, if specified will be called with the result of
#      |      every JSON object decoded with an ordered list of pairs.  The return
#      |      value of ``object_pairs_hook`` will be used instead of the ``dict``.
#      |      This feature can be used to implement custom decoders that rely on the
#      |      order that the key and value pairs are decoded (for example,
#      |      collections.OrderedDict will remember the order of insertion). If
#      |      ``object_hook`` is also defined, the ``object_pairs_hook`` takes
#      |      priority.
#      |
#      |      ``parse_float``, if specified, will be called with the string
#      |      of every JSON float to be decoded. By default this is equivalent to
#      |      float(num_str). This can be used to use another datatype or parser
#      |      for JSON floats (e.g. decimal.Decimal).
#      |
#      |      ``parse_int``, if specified, will be called with the string
#      |      of every JSON int to be decoded. By default this is equivalent to
#      |      int(num_str). This can be used to use another datatype or parser
#      |      for JSON integers (e.g. float).
#      |
#      |      ``parse_constant``, if specified, will be called with one of the
#      |      following strings: -Infinity, Infinity, NaN.
#      |      This can be used to raise an exception if invalid JSON numbers
#      |      are encountered.
#      |
#      |      If ``strict`` is false (true is the default), then control
#      |      characters will be allowed inside strings.  Control characters in
#      |      this context are those with character codes in the 0-31 range,
#      |      including ``'\t'`` (tab), ``'\n'``, ``'\r'`` and ``'\0'``.
#      |
#      |  decode(self, s, _w=<built-in method match of _sre.SRE_Pattern object at 0x7f407cafa6f0>)
#      |      Return the Python representation of ``s`` (a ``str`` instance
#      |      containing a JSON document).
#      |
#      |  raw_decode(self, s, idx=0)
#      |      Decode a JSON document from ``s`` (a ``str`` beginning with
#      |      a JSON document) and return a 2-tuple of the Python
#      |      representation and the index in ``s`` where the document ended.
#      |
#      |      This can be used to decode a JSON document from a string that may
#      |      have extraneous data at the end.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class JSONEncoder(builtins.object)
#      |  Extensible JSON <http://json.org> encoder for Python data structures.
#      |
#      |  Supports the following objects and types by default:
#      |
#      |  +-------------------+---------------+
#      |  | Python            | JSON          |
#      |  +===================+===============+
#      |  | dict              | object        |
#      |  +-------------------+---------------+
#      |  | list, tuple       | array         |
#      |  +-------------------+---------------+
#      |  | str               | string        |
#      |  +-------------------+---------------+
#      |  | int, float        | number        |
#      |  +-------------------+---------------+
#      |  | True              | true          |
#      |  +-------------------+---------------+
#      |  | False             | false         |
#      |  +-------------------+---------------+
#      |  | None              | null          |
#      |  +-------------------+---------------+
#      |
#      |  To extend this to recognize other objects, subclass and implement a
#      |  ``.default()`` method with another method that returns a serializable
#      |  object for ``o`` if possible, otherwise it should call the superclass
#      |  implementation (to raise ``TypeError``).
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, sort_keys=False, indent=None, separators=None, default=None)
#      |      Constructor for JSONEncoder, with sensible defaults.
#      |
#      |      If skipkeys is false, then it is a TypeError to attempt
#      |      encoding of keys that are not str, int, float or None.  If
#      |      skipkeys is True, such items are simply skipped.
#      |
#      |      If ensure_ascii is true, the output is guaranteed to be str
#      |      objects with all incoming non-ASCII characters escaped.  If
#      |      ensure_ascii is false, the output can contain non-ASCII characters.
#      |
#      |      If check_circular is true, then lists, dicts, and custom encoded
#      |      objects will be checked for circular references during encoding to
#      |      prevent an infinite recursion (which would cause an OverflowError).
#      |      Otherwise, no such check takes place.
#      |
#      |      If allow_nan is true, then NaN, Infinity, and -Infinity will be
#      |      encoded as such.  This behavior is not JSON specification compliant,
#      |      but is consistent with most JavaScript based encoders and decoders.
#      |      Otherwise, it will be a ValueError to encode such floats.
#      |
#      |      If sort_keys is true, then the output of dictionaries will be
#      |      sorted by key; this is useful for regression tests to ensure
#      |      that JSON serializations can be compared on a day-to-day basis.
#      |
#      |      If indent is a non-negative integer, then JSON array
#      |      elements and object members will be pretty-printed with that
#      |      indent level.  An indent level of 0 will only insert newlines.
#      |      None is the most compact representation.
#      |
#      |      If specified, separators should be an (item_separator, key_separator)
#      |      tuple.  The default is (', ', ': ') if *indent* is ``None`` and
#      |      (',', ': ') otherwise.  To get the most compact JSON representation,
#      |      you should specify (',', ':') to eliminate whitespace.
#      |
#      |      If specified, default is a function that gets called for objects
#      |      that can't otherwise be serialized.  It should return a JSON encodable
#      |      version of the object or raise a ``TypeError``.
#      |
#      |  default(self, o)
#      |      Implement this method in a subclass such that it returns
#      |      a serializable object for ``o``, or calls the base implementation
#      |      (to raise a ``TypeError``).
#      |
#      |      For example, to support arbitrary iterators, you could
#      |      implement default like this::
#      |
#      |          def default(self, o):
#      |              try:
#      |                  iterable = iter(o)
#      |              except TypeError:
#      |                  pass
#      |              else:
#      |                  return list(iterable)
#      |              # Let the base class default method raise the TypeError
#      |              return JSONEncoder.default(self, o)
#      |
#      |  encode(self, o)
#      |      Return a JSON string representation of a Python data structure.
#      |
#      |      >>> from json.encoder import JSONEncoder
#      |      >>> JSONEncoder().encode({"foo": ["bar", "baz"]})
#      |      '{"foo": ["bar", "baz"]}'
#      |
#      |  iterencode(self, o, _one_shot=False)
#      |      Encode the given object and yield each string
#      |      representation as available.
#      |
#      |      For example::
#      |
#      |          for chunk in JSONEncoder().iterencode(bigobject):
#      |              mysocket.write(chunk)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  item_separator = ', '
#      |
#      |  key_separator = ': '
#
# FUNCTIONS
#     dump(obj, fp, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)
#         Serialize ``obj`` as a JSON formatted stream to ``fp`` (a
#         ``.write()``-supporting file-like object).
#
#         If ``skipkeys`` is true then ``dict`` keys that are not basic types
#         (``str``, ``int``, ``float``, ``bool``, ``None``) will be skipped
#         instead of raising a ``TypeError``.
#
#         If ``ensure_ascii`` is false, then the strings written to ``fp`` can
#         contain non-ASCII characters if they appear in strings contained in
#         ``obj``. Otherwise, all such characters are escaped in JSON strings.
#
#         If ``check_circular`` is false, then the circular reference check
#         for container types will be skipped and a circular reference will
#         result in an ``OverflowError`` (or worse).
#
#         If ``allow_nan`` is false, then it will be a ``ValueError`` to
#         serialize out of range ``float`` values (``nan``, ``inf``, ``-inf``)
#         in strict compliance of the JSON specification, instead of using the
#         JavaScript equivalents (``NaN``, ``Infinity``, ``-Infinity``).
#
#         If ``indent`` is a non-negative integer, then JSON array elements and
#         object members will be pretty-printed with that indent level. An indent
#         level of 0 will only insert newlines. ``None`` is the most compact
#         representation.
#
#         If specified, ``separators`` should be an ``(item_separator, key_separator)``
#         tuple.  The default is ``(', ', ': ')`` if *indent* is ``None`` and
#         ``(',', ': ')`` otherwise.  To get the most compact JSON representation,
#         you should specify ``(',', ':')`` to eliminate whitespace.
#
#         ``default(obj)`` is a function that should return a serializable version
#         of obj or raise TypeError. The default simply raises TypeError.
#
#         If *sort_keys* is ``True`` (default: ``False``), then the output of
#         dictionaries will be sorted by key.
#
#         To use a custom ``JSONEncoder`` subclass (e.g. one that overrides the
#         ``.default()`` method to serialize additional types), specify it with
#         the ``cls`` kwarg; otherwise ``JSONEncoder`` is used.
#
#     dumps(obj, skipkeys=False, ensure_ascii=True, check_circular=True, allow_nan=True, cls=None, indent=None, separators=None, default=None, sort_keys=False, **kw)
#         Serialize ``obj`` to a JSON formatted ``str``.
#
#         If ``skipkeys`` is true then ``dict`` keys that are not basic types
#         (``str``, ``int``, ``float``, ``bool``, ``None``) will be skipped
#         instead of raising a ``TypeError``.
#
#         If ``ensure_ascii`` is false, then the return value can contain non-ASCII
#         characters if they appear in strings contained in ``obj``. Otherwise, all
#         such characters are escaped in JSON strings.
#
#         If ``check_circular`` is false, then the circular reference check
#         for container types will be skipped and a circular reference will
#         result in an ``OverflowError`` (or worse).
#
#         If ``allow_nan`` is false, then it will be a ``ValueError`` to
#         serialize out of range ``float`` values (``nan``, ``inf``, ``-inf``) in
#         strict compliance of the JSON specification, instead of using the
#         JavaScript equivalents (``NaN``, ``Infinity``, ``-Infinity``).
#
#         If ``indent`` is a non-negative integer, then JSON array elements and
#         object members will be pretty-printed with that indent level. An indent
#         level of 0 will only insert newlines. ``None`` is the most compact
#         representation.
#
#         If specified, ``separators`` should be an ``(item_separator, key_separator)``
#         tuple.  The default is ``(', ', ': ')`` if *indent* is ``None`` and
#         ``(',', ': ')`` otherwise.  To get the most compact JSON representation,
#         you should specify ``(',', ':')`` to eliminate whitespace.
#
#         ``default(obj)`` is a function that should return a serializable version
#         of obj or raise TypeError. The default simply raises TypeError.
#
#         If *sort_keys* is ``True`` (default: ``False``), then the output of
#         dictionaries will be sorted by key.
#
#         To use a custom ``JSONEncoder`` subclass (e.g. one that overrides the
#         ``.default()`` method to serialize additional types), specify it with
#         the ``cls`` kwarg; otherwise ``JSONEncoder`` is used.
#
#     load(fp, cls=None, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, object_pairs_hook=None, **kw)
#         Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#         a JSON document) to a Python object.
#
#         ``object_hook`` is an optional function that will be called with the
#         result of any object literal decode (a ``dict``). The return value of
#         ``object_hook`` will be used instead of the ``dict``. This feature
#         can be used to implement custom decoders (e.g. JSON-RPC class hinting).
#
#         ``object_pairs_hook`` is an optional function that will be called with the
#         result of any object literal decoded with an ordered list of pairs.  The
#         return value of ``object_pairs_hook`` will be used instead of the ``dict``.
#         This feature can be used to implement custom decoders that rely on the
#         order that the key and value pairs are decoded (for example,
#         collections.OrderedDict will remember the order of insertion). If
#         ``object_hook`` is also defined, the ``object_pairs_hook`` takes priority.
#
#         To use a custom ``JSONDecoder`` subclass, specify it with the ``cls``
#         kwarg; otherwise ``JSONDecoder`` is used.
#
#     loads(s, encoding=None, cls=None, object_hook=None, parse_float=None, parse_int=None, parse_constant=None, object_pairs_hook=None, **kw)
#         Deserialize ``s`` (a ``str`` instance containing a JSON
#         document) to a Python object.
#
#         ``object_hook`` is an optional function that will be called with the
#         result of any object literal decode (a ``dict``). The return value of
#         ``object_hook`` will be used instead of the ``dict``. This feature
#         can be used to implement custom decoders (e.g. JSON-RPC class hinting).
#
#         ``object_pairs_hook`` is an optional function that will be called with the
#         result of any object literal decoded with an ordered list of pairs.  The
#         return value of ``object_pairs_hook`` will be used instead of the ``dict``.
#         This feature can be used to implement custom decoders that rely on the
#         order that the key and value pairs are decoded (for example,
#         collections.OrderedDict will remember the order of insertion). If
#         ``object_hook`` is also defined, the ``object_pairs_hook`` takes priority.
#
#         ``parse_float``, if specified, will be called with the string
#         of every JSON float to be decoded. By default this is equivalent to
#         float(num_str). This can be used to use another datatype or parser
#         for JSON floats (e.g. decimal.Decimal).
#
#         ``parse_int``, if specified, will be called with the string
#         of every JSON int to be decoded. By default this is equivalent to
#         int(num_str). This can be used to use another datatype or parser
#         for JSON integers (e.g. float).
#
#         ``parse_constant``, if specified, will be called with one of the
#         following strings: -Infinity, Infinity, NaN, null, true, false.
#         This can be used to raise an exception if invalid JSON numbers
#         are encountered.
#
#         To use a custom ``JSONDecoder`` subclass, specify it with the ``cls``
#         kwarg; otherwise ``JSONDecoder`` is used.
#
#         The ``encoding`` argument is ignored and deprecated.
#
# DATA
#     __all__ = ['dump', 'dumps', 'load', 'loads', 'JSONDecoder', 'JSONDecod...
#
# VERSION
#     2.0.9
#
# AUTHOR
#     Bob Ippolito <bob@redivi.com>
#
# FILE
#     /usr/lib/python3.5/json/__init__.py

# %%
dosages = [
    dict( drug="Aspirin", amount=100, mass_unit="mg", time_unit="hr"),
    dict( drug="Digoxin", amount=50,  mass_unit="mg", time_unit="hr")
]

# %%
dosages
# Out:
# [{'amount': 100, 'drug': 'Aspirin', 'mass_unit': 'mg', 'time_unit': 'hr'},
#  {'amount': 50, 'drug': 'Digoxin', 'mass_unit': 'mg', 'time_unit': 'hr'}]

# %%
print(json.dumps(dosages))
# Out:
# [{"time_unit": "hr", "amount": 100, "mass_unit": "mg", "drug": "Aspirin"}, {"time_unit": "hr", "amount": 50, "mass_unit": "mg", "drug": "Digoxin"}]

# %%
type(dosages)
# Out:
# list

# %%
dosages
# Out:
# [{'amount': 100, 'drug': 'Aspirin', 'mass_unit': 'mg', 'time_unit': 'hr'},
#  {'amount': 50, 'drug': 'Digoxin', 'mass_unit': 'mg', 'time_unit': 'hr'}]

# %%
print(json.dumps(dosages, indent=4))
# Out:
# [
#     {
#         "time_unit": "hr",
#         "amount": 100,
#         "mass_unit": "mg",
#         "drug": "Aspirin"
#     },
#     {
#         "time_unit": "hr",
#         "amount": 50,
#         "mass_unit": "mg",
#         "drug": "Digoxin"
#     }
# ]

# %%
json.dumps(dosages, indent=4)[0:10]
# Out:
# '[\n    {\n  '

# %%
with open('dosages.json','w') as dosefile:
    json.dump(dosages, dosefile, indent=4)
    #dosefile.write(json.dumps(dosages, indent=4))

# %%
# %%bash
# cat dosages.json
# Out:
# [
#     {
#         "time_unit": "hr",
#         "amount": 100,
#         "mass_unit": "mg",
#         "drug": "Aspirin"
#     },
#     {
#         "time_unit": "hr",
#         "amount": 50,
#         "mass_unit": "mg",
#         "drug": "Digoxin"
#     }
# ]

# %% [markdown]
# ## Reading JSON into Python

# %%
with open('dosages.json') as dosefile:
    b = json.load(dosefile)
d
# Out:
# [{'amount': 100, 'drug': 'Aspirin', 'mass_unit': 'mg', 'time_unit': 'hr'},
#  {'amount': 50, 'drug': 'Digoxin', 'mass_unit': 'mg', 'time_unit': 'hr'}]

# %%
type(d)
# Out:
# list

# %%
ages = """{"E18734": 32,"E98904": 12,"E98743": 87}"""

# %%
ages
# Out:
# '{"E18734": 32,"E98904": 12,"E98743": 87}'

# %%
ages_dict = json.loads(ages)

# %%
ages_dict
# Out:
# {'E18734': 32, 'E98743': 87, 'E98904': 12}

# %%
type(ages_dict)
# Out:
# dict

# %%
data = "87"
val = json.loads(data)
val
# Out:
# 87

# %%
f = """
{"amount": 100}
{"amount": 50}
"""

# %%
json.loads(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-34-8610a5f04495> in <module>()
# ----> 1 json.loads(f)
#
# /usr/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /usr/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     340         end = _w(s, end).end()
#     341         if end != len(s):
# --> 342             raise JSONDecodeError("Extra data", s, end)
#     343         return obj
#     344
#
# JSONDecodeError: Extra data: line 3 column 1 (char 17)

# %% [markdown]
# ## JSON in Healthcare
#
# A new part of the HL7 standard is something called FHIR ("fire").  I've downloaded and stored a sample FHIR document in `/data/patient-example-a.json`
#
# https://www.hl7.org/fhir/patient-example-a.json.html

# %%
with open('/data/patient-example-a.json') as patfile:
    pat = json.load(patfile)

# %%
type(pat)
# Out:
# dict

# %%
pat.keys()
# Out:
# dict_keys(['gender', 'text', 'link', 'id', 'resourceType', 'name', 'managingOrganization', 'identifier', 'photo', 'active', 'contact'])

# %%
pat['gender']
# Out:
# 'male'

# %%
pat['name']
# Out:
# [{'family': 'Donald', 'given': ['Duck'], 'use': 'official'}]

# %%
pat['name'][0]
# Out:
# {'family': 'Donald', 'given': ['Duck'], 'use': 'official'}

# %%
pat['name'][0]['family']
# Out:
# 'Donald'

# %%
pat['name'][0]['family'][0]
# Out:
# 'D'

# %%
pat['name'][0]['family'] + ' ' + pat['name'][0]['given'][0]
# Out:
# 'Donald Duck'

# %%
pat['name'].append({'use':'alias', 'family':'Mickey', 'given':['Mouse']})

# %%
pat['name']
# Out:
# [{'family': 'Donald', 'given': ['Duck'], 'use': 'official'},
#  {'family': 'Mickey', 'given': ['Mouse'], 'use': 'alias'}]

# %%
pat['problem']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-82380810e916> in <module>()
# ----> 1 pat['problem']
#
# KeyError: 'problem'

# %%
pat['problem'] = ['annoying', 'yellow']

# %%
pat.keys()
# Out:
# dict_keys(['link', 'id', 'managingOrganization', 'contact', 'photo', 'problem', 'gender', 'text', 'resourceType', 'name', 'identifier', 'active'])

# %%
print(json.dumps(pat, indent=2))
# Out:
# {
#   "link": [
#     {
#       "type": "seealso",
#       "other": {
#         "reference": "Patient/pat2"
#       }
#     }
#   ],
#   "id": "pat1",
#   "managingOrganization": {
#     "display": "ACME Healthcare, Inc",
#     "reference": "Organization/1"
#   },
#   "contact": [
#     {
#       "relationship": [
#         {
#           "coding": [
#             {
#               "code": "E",
#               "system": "http://hl7.org/fhir/v2/0131"
#             }
#           ]
#         }
#       ],
#       "organization": {
#         "display": "Walt Disney Corporation",
#         "reference": "Organization/1"
#       }
#     }
#   ],
#   "photo": [
#     {
#       "data": "...",
#       "contentType": "image/gif"
#     }
#   ],
#   "problem": [
#     "annoying",
#     "yellow"
#   ],
#   "gender": "male",
#   "text": {
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\">\n      \n      <p>Patient Donald DUCK @ Acme Healthcare, Inc. MR = 654321</p>\n    \n    </div>",
#     "status": "generated"
#   },
#   "resourceType": "Patient",
#   "name": [
#     {
#       "family": "Donald",
#       "use": "official",
#       "given": [
#         "Duck"
#       ]
#     },
#     {
#       "family": "Mickey",
#       "use": "alias",
#       "given": [
#         "Mouse"
#       ]
#     }
#   ],
#   "identifier": [
#     {
#       "type": {
#         "coding": [
#           {
#             "code": "MR",
#             "system": "http://hl7.org/fhir/v2/0203"
#           }
#         ]
#       },
#       "use": "usual",
#       "system": "urn:oid:0.1.2.3.4.5.6.7",
#       "value": "654321"
#     }
#   ],
#   "active": true
# }

# %% [markdown]
# ## Another HL7 FHIR Example
#
# https://www.hl7.org/fhir/patient-example-f001-pieter.json.html
#
# `/data/patient-example-f001-pieter.json`

# %%
with open('/data/patient-example-f001-pieter.json') as patfile:
    pat = json.load(patfile)

print(json.dumps(pat, indent=4))
# Out:
# {
#     "communication": [
#         {
#             "preferred": true,
#             "language": {
#                 "coding": [
#                     {
#                         "display": "Dutch",
#                         "code": "nl",
#                         "system": "urn:ietf:bcp:47"
#                     }
#                 ],
#                 "text": "Nederlands"
#             }
#         }
#     ],
#     "multipleBirthBoolean": true,
#     "maritalStatus": {
#         "coding": [
#             {
#                 "display": "Married",
#                 "code": "M",
#                 "system": "http://hl7.org/fhir/v3/MaritalStatus"
#             }
#         ],
#         "text": "Getrouwd"
#     },
#     "id": "f001",
#     "deceasedBoolean": false,
#     "managingOrganization": {
#         "display": "Burgers University Medical Centre",
#         "reference": "Organization/f001"
#     },
#     "contact": [
#         {
#             "name": {
#                 "family": "Abels",
#                 "use": "usual",
#                 "given": [
#                     "Sarah"
#                 ]
#             },
#             "relationship": [
#                 {
#                     "coding": [
#                         {
#                             "code": "C",
#                             "system": "http://hl7.org/fhir/v2/0131"
#                         }
#                     ]
#                 }
#             ],
#             "telecom": [
#                 {
#                     "value": "0690383372",
#                     "system": "phone",
#                     "use": "mobile"
#                 }
#             ]
#         }
#     ],
#     "telecom": [
#         {
#             "value": "0648352638",
#             "system": "phone",
#             "use": "mobile"
#         },
#         {
#             "value": "p.heuvel@gmail.com",
#             "system": "email",
#             "use": "home"
#         }
#     ],
#     "birthDate": "1944-11-17",
#     "gender": "male",
#     "text": {
#         "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Generated Narrative with Details</b></p><p><b>id</b>: f001</p><p><b>identifier</b>: 738472983 (USUAL), ?? (USUAL)</p><p><b>active</b>: true</p><p><b>name</b>: Pieter van de Heuvel </p><p><b>telecom</b>: ph: 0648352638(MOBILE), p.heuvel@gmail.com(HOME)</p><p><b>gender</b>: male</p><p><b>birthDate</b>: 17/11/1944</p><p><b>deceased</b>: false</p><p><b>address</b>: Van Egmondkade 23 Amsterdam 1024 RJ NLD (HOME)</p><p><b>maritalStatus</b>: Getrouwd <span>(Details : {http://hl7.org/fhir/v3/MaritalStatus code 'M' = 'Married', given as 'Married'})</span></p><p><b>multipleBirth</b>: true</p><h3>Contacts</h3><table><tr><td>-</td><td><b>Relationship</b></td><td><b>Name</b></td><td><b>Telecom</b></td></tr><tr><td>*</td><td>Emergency Contact <span>(Details : {http://hl7.org/fhir/v2/0131 code 'C' = 'Emergency Contact)</span></td><td>Sarah Abels </td><td>ph: 0690383372(MOBILE)</td></tr></table><h3>Communications</h3><table><tr><td>-</td><td><b>Language</b></td><td><b>Preferred</b></td></tr><tr><td>*</td><td>Nederlands <span>(Details : {urn:ietf:bcp:47 code 'nl' = 'Dutch', given as 'Dutch'})</span></td><td>true</td></tr></table><p><b>managingOrganization</b>: <a>Burgers University Medical Centre</a></p></div>",
#         "status": "generated"
#     },
#     "resourceType": "Patient",
#     "name": [
#         {
#             "family": "van de Heuvel",
#             "suffix": [
#                 "MSc"
#             ],
#             "use": "usual",
#             "given": [
#                 "Pieter"
#             ]
#         }
#     ],
#     "identifier": [
#         {
#             "use": "usual",
#             "system": "urn:oid:2.16.840.1.113883.2.4.6.3",
#             "value": "738472983"
#         },
#         {
#             "use": "usual",
#             "system": "urn:oid:2.16.840.1.113883.2.4.6.3"
#         }
#     ],
#     "active": true,
#     "address": [
#         {
#             "postalCode": "1024 RJ",
#             "city": "Amsterdam",
#             "use": "home",
#             "country": "NLD",
#             "line": [
#                 "Van Egmondkade 23"
#             ]
#         }
#     ]
# }

# %%
print(pat['name'])

# %% [markdown]
# # Load from string

# %%
s = '{ "one": 1, "two": 2}'

# %%
s

# %%
s_obj = json.loads(s)

# %%
s_obj

# %%
type(s_obj)

# %% [markdown]
# Load JSON using Pandas
# ===
#
# Remember that a Pandas data frame is a rectangular 2-dimensional matrix.  JSON is hierarchical.  Yet, Pandas will try to load JSON data if it can figure out a way to unwrap the structure from a hierarchy into a matrix.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_json.html

# %%
# %%bash
# cat /data/dosages.json
# Out:
# [
#     {
#         "time_unit": "hr",
#         "amount": 100,
#         "mass_unit": "mg",
#         "drug": "Aspirin"
#     },
#     {
#         "time_unit": "hr",
#         "amount": 50,
#         "mass_unit": "mg",
#         "drug": "Digoxin"
#     }
# ]

# %%
import pandas as pd

df = pd.read_json('/data/dosages.json')

# %%
df
# Out:
#    amount     drug mass_unit time_unit
# 0     100  Aspirin        mg        hr
# 1      50  Digoxin        mg        hr

# %%
fhir = pd.read_json('/data/patient-example-f001-pieter.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-98dfebfbb6b8> in <module>()
# ----> 1 fhir = pd.read_json('/data/patient-example-f001-pieter.json')
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df.loc[df['drug'] == 'Aspirin']
# Out:
#    amount     drug mass_unit time_unit
# 0     100  Aspirin        mg        hr

# %% [markdown]
# Sometimes the JSON isn't "pretty"
# ===
#
# For these examples, we're pulling air quality data from the CDC website.
# https://ephtracking.cdc.gov/DataExplorer/#/
#
#
# CDC has a web API that makes downloading data programable.  Here is an example link.  Reviewing the documentation, we can actually see what the various parts of this URL mean.
#
#
#
# https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0
#
# The CDC website returns data using JSON.

# %%
import pandas as pd

data = pd.read_json('https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-9409cb22f108> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_json('https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0')
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# /usr/local/lib/python3.5/dist-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# Reading web data using `requests`
# ===
#
# Since the JSON that we're reading from the web has a bunch of extra metadata wrapped around the records themselves, we'll have to load that to Pandas a different way.  Our steps will be:
#
# 1. Load data from web using `requests`
# 2. Convert the text we get back from `JSON` to a Python dictionary
# 3. Use `Pandas.DataFrame.from_dict` to convert that to a `DataFrame`

# %%
import requests
import json

web_data = requests.get('https://ephtracking.cdc.gov/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0')

# %%
dir(web_data)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
data = json.loads(web_data.text)

# %%
data
# Out:
# {'benchmarkInformation': {'active': None,
#   'benchmarkFullName': 'National  Ambient Air Quality Standard',
#   'benchmarkId': 1,
#   'benchmarkName': ' Ambient Air Quality Standard',
#   'benchmarkShortName': ' Ambient Air Quality Standard',
#   'geographicDisplay': 'National',
#   'geographicTypeDisplay': 'National Benchmark',
#   'hasChart': False,
#   'hasMap': True,
#   'hasTable': True,
#   'id': 9,
#   'measureGeographicTypeId': 2,
#   'measureId': 296,
#   'multipleSelectionAction': 'Continue',
#   'multipleSelectionActionId': 1,
#   'units': 'µg/m³'},
#  'benchmarkResult': [{'calculationType': None,
#    'dataValue': '12.0',
#    'displayValue': '12.0',
#    'geo': None,
#    'geoAbbreviation': None,
#    'geoId': None,
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '31',
#    'parentGeo': None,
#    'parentGeoAbbreviation': None,
#    'parentGeoId': None,
#    'year': '2013'},
#   {'calculationType': None,
#    'dataValue': '12.0',
#    'displayValue': '12.0',
#    'geo': None,
#    'geoAbbreviation': None,
#    'geoId': None,
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '32',
#    'parentGeo': None,
#    'parentGeoAbbreviation': None,
#    'parentGeoId': None,
#    'year': '2014'}],
#  'biomonitoringTableResult': [],
#  'categoryTableResult': [],
#  'climateChangeTableResult': [],
#  'dailyEstimatesTableResult': [],
#  'devDisabilitiesTableResult': [],
#  'fullPublicAPIUrl': 'https://ephtracking.cdc.gov:443/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0?apiToken=8E399938-9011-4019-9AEC-4E11DBF18F10&otherValue=969a1bf37c340401629355a5224934fcfb6b87f6397eb3e9b89194174e0432c9b42dcee92ac658dde077d253a2d66f8a0fd14eb9a5b58c6&timeStamp=1522715355578',
#  'healthImpactTableResult': [],
#  'heatEpisodesTableResult': [],
#  'legendResult': [],
#  'lookupList': {},
#  'measureInformationDTO': {'chartAxisExceptionDTO': [],
#   'chartDisplayDTO': [],
#   'mapDisplayDTO': [],
#   'measureCalculationExceptionDTO': [],
#   'measureDisplayException': [],
#   'measureInformation': {'calculation': None,
#    'calculationColumnName': None,
#    'calculationId': 0,
#    'calculationType': None,
#    'colorCount': None,
#    'confidenceIntervalName': None,
#    'defaultBreakGroupCount': None,
#    'defaultDataClassificationTypeId': None,
#    'hasConfidenceInterval': None,
#    'hasMultiMeasure': None,
#    'hasStability': None,
#    'parentTemporalType': None,
#    'precision': 0,
#    'smoothingType': None,
#    'temporalColumnName': None,
#    'temporalCount': 0,
#    'temporalType': None,
#    'units': None},
#   'tableDisplayDTO': []},
#  'measureStratificationLevel': {'id': 0,
#   'measureId': 0,
#   'smoothingTypeId': 0,
#   'stratificationLevelId': 0,
#   'suppressionTypeId': 0},
#  'modeledTableResult': [{'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Adair',
#    'geoAbbreviation': '29001',
#    'geoId': '29001',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252343',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Adair, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Adair',
#    'geoAbbreviation': '29001',
#    'geoId': '29001',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252344',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Adair, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Andrew',
#    'geoAbbreviation': '29003',
#    'geoId': '29003',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252357',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Andrew, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Andrew',
#    'geoAbbreviation': '29003',
#    'geoId': '29003',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252358',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Andrew, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '8.9',
#    'displayValue': '8.9',
#    'geo': 'Atchison',
#    'geoAbbreviation': '29005',
#    'geoId': '29005',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252371',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 8.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Atchison, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Atchison',
#    'geoAbbreviation': '29005',
#    'geoId': '29005',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252372',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Atchison, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Audrain',
#    'geoAbbreviation': '29007',
#    'geoId': '29007',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252385',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Audrain, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.0',
#    'displayValue': '10.0',
#    'geo': 'Audrain',
#    'geoAbbreviation': '29007',
#    'geoId': '29007',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252386',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Audrain, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Barry',
#    'geoAbbreviation': '29009',
#    'geoId': '29009',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252399',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Barry, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Barry',
#    'geoAbbreviation': '29009',
#    'geoId': '29009',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252400',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Barry, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Barton',
#    'geoAbbreviation': '29011',
#    'geoId': '29011',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252413',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Barton, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Barton',
#    'geoAbbreviation': '29011',
#    'geoId': '29011',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252414',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Barton, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Bates',
#    'geoAbbreviation': '29013',
#    'geoId': '29013',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252427',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Bates, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Bates',
#    'geoAbbreviation': '29013',
#    'geoId': '29013',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252428',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Bates, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Benton',
#    'geoAbbreviation': '29015',
#    'geoId': '29015',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252441',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Benton, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Benton',
#    'geoAbbreviation': '29015',
#    'geoId': '29015',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252442',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Benton, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Bollinger',
#    'geoAbbreviation': '29017',
#    'geoId': '29017',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252455',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Bollinger, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.5',
#    'displayValue': '10.5',
#    'geo': 'Bollinger',
#    'geoAbbreviation': '29017',
#    'geoId': '29017',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252456',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Bollinger, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Boone',
#    'geoAbbreviation': '29019',
#    'geoId': '29019',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252469',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Boone, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.1',
#    'displayValue': '10.1',
#    'geo': 'Boone',
#    'geoAbbreviation': '29019',
#    'geoId': '29019',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252470',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Boone, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Buchanan',
#    'geoAbbreviation': '29021',
#    'geoId': '29021',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252483',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Buchanan, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.2',
#    'displayValue': '10.2',
#    'geo': 'Buchanan',
#    'geoAbbreviation': '29021',
#    'geoId': '29021',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252484',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Buchanan, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Butler',
#    'geoAbbreviation': '29023',
#    'geoId': '29023',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252497',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Butler, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.8',
#    'displayValue': '10.8',
#    'geo': 'Butler',
#    'geoAbbreviation': '29023',
#    'geoId': '29023',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252498',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Butler, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Caldwell',
#    'geoAbbreviation': '29025',
#    'geoId': '29025',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252511',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Caldwell, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Caldwell',
#    'geoAbbreviation': '29025',
#    'geoId': '29025',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252512',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Caldwell, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Callaway',
#    'geoAbbreviation': '29027',
#    'geoId': '29027',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252525',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Callaway, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.0',
#    'displayValue': '10.0',
#    'geo': 'Callaway',
#    'geoAbbreviation': '29027',
#    'geoId': '29027',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252526',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Callaway, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Camden',
#    'geoAbbreviation': '29029',
#    'geoId': '29029',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252539',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Camden, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Camden',
#    'geoAbbreviation': '29029',
#    'geoId': '29029',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252540',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Camden, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.3',
#    'displayValue': '10.3',
#    'geo': 'Cape Girardeau',
#    'geoAbbreviation': '29031',
#    'geoId': '29031',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252553',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cape Girardeau, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '11.3',
#    'displayValue': '11.3',
#    'geo': 'Cape Girardeau',
#    'geoAbbreviation': '29031',
#    'geoId': '29031',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252554',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 11.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cape Girardeau, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Carroll',
#    'geoAbbreviation': '29033',
#    'geoId': '29033',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252567',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Carroll, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Carroll',
#    'geoAbbreviation': '29033',
#    'geoId': '29033',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252568',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Carroll, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Carter',
#    'geoAbbreviation': '29035',
#    'geoId': '29035',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252581',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Carter, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Carter',
#    'geoAbbreviation': '29035',
#    'geoId': '29035',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252582',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Carter, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.1',
#    'displayValue': '10.1',
#    'geo': 'Cass',
#    'geoAbbreviation': '29037',
#    'geoId': '29037',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252595',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cass, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Cass',
#    'geoAbbreviation': '29037',
#    'geoId': '29037',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252596',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cass, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Cedar',
#    'geoAbbreviation': '29039',
#    'geoId': '29039',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252609',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cedar, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Cedar',
#    'geoAbbreviation': '29039',
#    'geoId': '29039',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252610',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cedar, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Chariton',
#    'geoAbbreviation': '29041',
#    'geoId': '29041',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252623',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Chariton, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Chariton',
#    'geoAbbreviation': '29041',
#    'geoId': '29041',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252624',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Chariton, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Christian',
#    'geoAbbreviation': '29043',
#    'geoId': '29043',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252637',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Christian, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Christian',
#    'geoAbbreviation': '29043',
#    'geoId': '29043',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252638',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Christian, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Clark',
#    'geoAbbreviation': '29045',
#    'geoId': '29045',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252651',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clark, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.1',
#    'displayValue': '10.1',
#    'geo': 'Clark',
#    'geoAbbreviation': '29045',
#    'geoId': '29045',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252652',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clark, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.5',
#    'displayValue': '10.5',
#    'geo': 'Clay',
#    'geoAbbreviation': '29047',
#    'geoId': '29047',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252665',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clay, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.0',
#    'displayValue': '10.0',
#    'geo': 'Clay',
#    'geoAbbreviation': '29047',
#    'geoId': '29047',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252666',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clay, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Clinton',
#    'geoAbbreviation': '29049',
#    'geoId': '29049',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252679',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clinton, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Clinton',
#    'geoAbbreviation': '29049',
#    'geoId': '29049',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252680',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Clinton, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Cole',
#    'geoAbbreviation': '29051',
#    'geoId': '29051',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252693',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cole, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.0',
#    'displayValue': '10.0',
#    'geo': 'Cole',
#    'geoAbbreviation': '29051',
#    'geoId': '29051',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252694',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cole, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Cooper',
#    'geoAbbreviation': '29053',
#    'geoId': '29053',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252707',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cooper, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.7',
#    'displayValue': '9.7',
#    'geo': 'Cooper',
#    'geoAbbreviation': '29053',
#    'geoId': '29053',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252708',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Cooper, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Crawford',
#    'geoAbbreviation': '29055',
#    'geoId': '29055',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252721',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Crawford, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Crawford',
#    'geoAbbreviation': '29055',
#    'geoId': '29055',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252722',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Crawford, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Dade',
#    'geoAbbreviation': '29057',
#    'geoId': '29057',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252735',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dade, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Dade',
#    'geoAbbreviation': '29057',
#    'geoId': '29057',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252736',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dade, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Dallas',
#    'geoAbbreviation': '29059',
#    'geoId': '29059',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252749',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dallas, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Dallas',
#    'geoAbbreviation': '29059',
#    'geoId': '29059',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252750',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dallas, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Daviess',
#    'geoAbbreviation': '29061',
#    'geoId': '29061',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252763',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Daviess, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Daviess',
#    'geoAbbreviation': '29061',
#    'geoId': '29061',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252764',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Daviess, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'DeKalb',
#    'geoAbbreviation': '29063',
#    'geoId': '29063',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252777',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'DeKalb, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'DeKalb',
#    'geoAbbreviation': '29063',
#    'geoId': '29063',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252778',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'DeKalb, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Dent',
#    'geoAbbreviation': '29065',
#    'geoId': '29065',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252791',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dent, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Dent',
#    'geoAbbreviation': '29065',
#    'geoId': '29065',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252792',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dent, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Douglas',
#    'geoAbbreviation': '29067',
#    'geoId': '29067',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252805',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Douglas, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Douglas',
#    'geoAbbreviation': '29067',
#    'geoId': '29067',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252806',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Douglas, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.2',
#    'displayValue': '10.2',
#    'geo': 'Dunklin',
#    'geoAbbreviation': '29069',
#    'geoId': '29069',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252819',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dunklin, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '11.3',
#    'displayValue': '11.3',
#    'geo': 'Dunklin',
#    'geoAbbreviation': '29069',
#    'geoId': '29069',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252820',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 11.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Dunklin, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.4',
#    'displayValue': '10.4',
#    'geo': 'Franklin',
#    'geoAbbreviation': '29071',
#    'geoId': '29071',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252833',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Franklin, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.7',
#    'displayValue': '10.7',
#    'geo': 'Franklin',
#    'geoAbbreviation': '29071',
#    'geoId': '29071',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252834',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Franklin, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Gasconade',
#    'geoAbbreviation': '29073',
#    'geoId': '29073',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252847',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Gasconade, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Gasconade',
#    'geoAbbreviation': '29073',
#    'geoId': '29073',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252848',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Gasconade, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Gentry',
#    'geoAbbreviation': '29075',
#    'geoId': '29075',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252861',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Gentry, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Gentry',
#    'geoAbbreviation': '29075',
#    'geoId': '29075',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252862',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Gentry, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Greene',
#    'geoAbbreviation': '29077',
#    'geoId': '29077',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252875',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Greene, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.1',
#    'displayValue': '10.1',
#    'geo': 'Greene',
#    'geoAbbreviation': '29077',
#    'geoId': '29077',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252876',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Greene, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Grundy',
#    'geoAbbreviation': '29079',
#    'geoId': '29079',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252889',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Grundy, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Grundy',
#    'geoAbbreviation': '29079',
#    'geoId': '29079',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252890',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Grundy, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '8.9',
#    'displayValue': '8.9',
#    'geo': 'Harrison',
#    'geoAbbreviation': '29081',
#    'geoId': '29081',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252903',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 8.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Harrison, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Harrison',
#    'geoAbbreviation': '29081',
#    'geoId': '29081',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252904',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Harrison, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Henry',
#    'geoAbbreviation': '29083',
#    'geoId': '29083',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252917',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Henry, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Henry',
#    'geoAbbreviation': '29083',
#    'geoId': '29083',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252918',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Henry, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Hickory',
#    'geoAbbreviation': '29085',
#    'geoId': '29085',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252931',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Hickory, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.2',
#    'displayValue': '9.2',
#    'geo': 'Hickory',
#    'geoAbbreviation': '29085',
#    'geoId': '29085',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252932',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Hickory, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Holt',
#    'geoAbbreviation': '29087',
#    'geoId': '29087',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252945',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Holt, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Holt',
#    'geoAbbreviation': '29087',
#    'geoId': '29087',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '252946',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
# ...
#    'geoId': '29189',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253673',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 12.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'St. Louis, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '12.1',
#    'displayValue': '12.1',
#    'geo': 'St. Louis',
#    'geoAbbreviation': '29189',
#    'geoId': '29189',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253674',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 12.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'St. Louis, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '11.2',
#    'displayValue': '11.2',
#    'geo': 'St. Louis City',
#    'geoAbbreviation': '29510',
#    'geoId': '29510',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253939',
#    'modeledFlag': '0',
#    'noDataBreakGroup': 0,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 11.2'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'St. Louis City, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '11.5',
#    'displayValue': '11.5',
#    'geo': 'St. Louis City',
#    'geoAbbreviation': '29510',
#    'geoId': '29510',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253940',
#    'modeledFlag': '0',
#    'noDataBreakGroup': 0,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 11.5'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'St. Louis City, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.0',
#    'displayValue': '10.0',
#    'geo': 'Ste. Genevieve',
#    'geoAbbreviation': '29186',
#    'geoId': '29186',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253645',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Ste. Genevieve, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.6',
#    'displayValue': '10.6',
#    'geo': 'Ste. Genevieve',
#    'geoAbbreviation': '29186',
#    'geoId': '29186',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253646',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Ste. Genevieve, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.3',
#    'displayValue': '10.3',
#    'geo': 'Stoddard',
#    'geoAbbreviation': '29207',
#    'geoId': '29207',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253771',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Stoddard, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '11.3',
#    'displayValue': '11.3',
#    'geo': 'Stoddard',
#    'geoAbbreviation': '29207',
#    'geoId': '29207',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253772',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 11.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Stoddard, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Stone',
#    'geoAbbreviation': '29209',
#    'geoId': '29209',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253785',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Stone, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Stone',
#    'geoAbbreviation': '29209',
#    'geoId': '29209',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253786',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Stone, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Sullivan',
#    'geoAbbreviation': '29211',
#    'geoId': '29211',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253799',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Sullivan, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Sullivan',
#    'geoAbbreviation': '29211',
#    'geoId': '29211',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253800',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Sullivan, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Taney',
#    'geoAbbreviation': '29213',
#    'geoId': '29213',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253813',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Taney, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.8',
#    'displayValue': '9.8',
#    'geo': 'Taney',
#    'geoAbbreviation': '29213',
#    'geoId': '29213',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253814',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.8 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Taney, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Texas',
#    'geoAbbreviation': '29215',
#    'geoId': '29215',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253827',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Texas, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Texas',
#    'geoAbbreviation': '29215',
#    'geoId': '29215',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253828',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Texas, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Vernon',
#    'geoAbbreviation': '29217',
#    'geoId': '29217',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253841',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Vernon, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Vernon',
#    'geoAbbreviation': '29217',
#    'geoId': '29217',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253842',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Vernon, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '10.2',
#    'displayValue': '10.2',
#    'geo': 'Warren',
#    'geoAbbreviation': '29219',
#    'geoId': '29219',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253855',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.2 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Warren, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.5',
#    'displayValue': '10.5',
#    'geo': 'Warren',
#    'geoAbbreviation': '29219',
#    'geoId': '29219',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253856',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Warren, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Washington',
#    'geoAbbreviation': '29221',
#    'geoId': '29221',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253869',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Washington, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.9',
#    'displayValue': '9.9',
#    'geo': 'Washington',
#    'geoAbbreviation': '29221',
#    'geoId': '29221',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253870',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.9 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Washington, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.4',
#    'displayValue': '9.4',
#    'geo': 'Wayne',
#    'geoAbbreviation': '29223',
#    'geoId': '29223',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253883',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.4 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Wayne, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '10.1',
#    'displayValue': '10.1',
#    'geo': 'Wayne',
#    'geoAbbreviation': '29223',
#    'geoId': '29223',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253884',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 10.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Wayne, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.3',
#    'displayValue': '9.3',
#    'geo': 'Webster',
#    'geoAbbreviation': '29225',
#    'geoId': '29225',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253897',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.3 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Webster, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.6',
#    'displayValue': '9.6',
#    'geo': 'Webster',
#    'geoAbbreviation': '29225',
#    'geoId': '29225',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253898',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.6 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Webster, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '8.7',
#    'displayValue': '8.7',
#    'geo': 'Worth',
#    'geoAbbreviation': '29227',
#    'geoId': '29227',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253911',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 8.7 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Worth, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.0',
#    'displayValue': '9.0',
#    'geo': 'Worth',
#    'geoAbbreviation': '29227',
#    'geoId': '29227',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253912',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.0 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Worth, MO',
#    'year': '2014'},
#   {'calculationType': 'Average',
#    'dataValue': '9.1',
#    'displayValue': '9.1',
#    'geo': 'Wright',
#    'geoAbbreviation': '29229',
#    'geoId': '29229',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253925',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.1 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Wright, MO',
#    'year': '2013'},
#   {'calculationType': 'Average',
#    'dataValue': '9.5',
#    'displayValue': '9.5',
#    'geo': 'Wright',
#    'geoAbbreviation': '29229',
#    'geoId': '29229',
#    'geographicTypeId': 2,
#    'groupById': '1',
#    'id': '253926',
#    'modeledFlag': '1',
#    'noDataBreakGroup': 30,
#    'noDataId': -1,
#    'parentGeo': 'Missouri',
#    'parentGeoAbbreviation': 'MO',
#    'parentGeoId': '29',
#    'rollover': ['Average: 9.5 (Modeled)'],
#    'stabilityFlag': '1',
#    'suppressionFlag': '0',
#    'title': 'Wright, MO',
#    'year': '2014'}],
#  'publicAPIServerUrl': 'https://ephtracking.cdc.gov:443',
#  'publicAPIUrl': '/apigateway/api/v1/getCoreHolder/296/2/1/29/2014,2013/0/0?apiToken=8E399938-9011-4019-9AEC-4E11DBF18F10&otherValue=969a1bf37c340401629355a5224934fcfb6b87f6397eb3e9b89194174e0432c9b42dcee92ac658dde077d253a2d66f8a0fd14eb9a5b58c6&timeStamp=1522715355578',
#  'pwsTableResult': [],
#  'tableResult': [],
#  'tableResultClass': 'ModeledTableResult',
#  'tableResultWithCI': [],
#  'tableResultWithMonth': [],
#  'tableResultWithQuarter': [],
#  'tableReturnType': 'modeledTableResult'}

# %%
for key, val in data.items():
    print("{:30s} {:-5d}".format(key, len(val)))
# Out:
# biomonitoringTableResult           0
# categoryTableResult                0
# healthImpactTableResult            0
# climateChangeTableResult           0
# measureInformationDTO              7
# lookupList                         0
# fullPublicAPIUrl                 281
# heatEpisodesTableResult            0
# publicAPIServerUrl                31
# tableResultWithCI                  0
# tableResultWithMonth               0
# tableResultWithQuarter             0
# dailyEstimatesTableResult          0
# tableResult                        0
# benchmarkInformation              16
# devDisabilitiesTableResult         0
# benchmarkResult                    2
# legendResult                       0
# tableReturnType                   18
# tableResultClass                  18
# modeledTableResult               230
# publicAPIUrl                     250
# pwsTableResult                     0
# measureStratificationLevel         5

# %%
df = pd.DataFrame(data['modeledTableResult'])

# %%
df
# Out:
#     calculationType dataValue displayValue             geo geoAbbreviation  \
# 0           Average       9.1          9.1           Adair           29001
# 1           Average       9.5          9.5           Adair           29001
# 2           Average       9.3          9.3          Andrew           29003
# 3           Average       9.9          9.9          Andrew           29003
# 4           Average       8.9          8.9        Atchison           29005
# 5           Average       9.2          9.2        Atchison           29005
# 6           Average       9.7          9.7         Audrain           29007
# 7           Average      10.0         10.0         Audrain           29007
# 8           Average       9.5          9.5           Barry           29009
# 9           Average       9.8          9.8           Barry           29009
# 10          Average       9.3          9.3          Barton           29011
# 11          Average       9.3          9.3          Barton           29011
# 12          Average       9.3          9.3           Bates           29013
# 13          Average       9.4          9.4           Bates           29013
# 14          Average       9.2          9.2          Benton           29015
# 15          Average       9.4          9.4          Benton           29015
# 16          Average       9.7          9.7       Bollinger           29017
# 17          Average      10.5         10.5       Bollinger           29017
# 18          Average       9.8          9.8           Boone           29019
# 19          Average      10.1         10.1           Boone           29019
# 20          Average       9.6          9.6        Buchanan           29021
# 21          Average      10.2         10.2        Buchanan           29021
# 22          Average       9.9          9.9          Butler           29023
# 23          Average      10.8         10.8          Butler           29023
# 24          Average       9.2          9.2        Caldwell           29025
# 25          Average       9.3          9.3        Caldwell           29025
# 26          Average       9.8          9.8        Callaway           29027
# 27          Average      10.0         10.0        Callaway           29027
# 28          Average       9.4          9.4          Camden           29029
# 29          Average       9.8          9.8          Camden           29029
# ..              ...       ...          ...             ...             ...
# 200         Average      12.0         12.0       St. Louis           29189
# 201         Average      12.1         12.1       St. Louis           29189
# 202         Average      11.2         11.2  St. Louis City           29510
# 203         Average      11.5         11.5  St. Louis City           29510
# 204         Average      10.0         10.0  Ste. Genevieve           29186
# 205         Average      10.6         10.6  Ste. Genevieve           29186
# 206         Average      10.3         10.3        Stoddard           29207
# 207         Average      11.3         11.3        Stoddard           29207
# 208         Average       9.5          9.5           Stone           29209
# 209         Average       9.8          9.8           Stone           29209
# 210         Average       9.0          9.0        Sullivan           29211
# 211         Average       9.3          9.3        Sullivan           29211
# 212         Average       9.5          9.5           Taney           29213
# 213         Average       9.8          9.8           Taney           29213
# 214         Average       9.1          9.1           Texas           29215
# 215         Average       9.6          9.6           Texas           29215
# 216         Average       9.4          9.4          Vernon           29217
# 217         Average       9.4          9.4          Vernon           29217
# 218         Average      10.2         10.2          Warren           29219
# 219         Average      10.5         10.5          Warren           29219
# 220         Average       9.5          9.5      Washington           29221
# 221         Average       9.9          9.9      Washington           29221
# 222         Average       9.4          9.4           Wayne           29223
# 223         Average      10.1         10.1           Wayne           29223
# 224         Average       9.3          9.3         Webster           29225
# 225         Average       9.6          9.6         Webster           29225
# 226         Average       8.7          8.7           Worth           29227
# 227         Average       9.0          9.0           Worth           29227
# 228         Average       9.1          9.1          Wright           29229
# 229         Average       9.5          9.5          Wright           29229
#
#      geoId  geographicTypeId groupById      id modeledFlag  noDataBreakGroup  \
# 0    29001                 2         1  252343           1                30
# 1    29001                 2         1  252344           1                30
# 2    29003                 2         1  252357           1                30
# 3    29003                 2         1  252358           1                30
# 4    29005                 2         1  252371           1                30
# 5    29005                 2         1  252372           1                30
# 6    29007                 2         1  252385           1                30
# 7    29007                 2         1  252386           1                30
# 8    29009                 2         1  252399           1                30
# 9    29009                 2         1  252400           1                30
# 10   29011                 2         1  252413           1                30
# 11   29011                 2         1  252414           1                30
# 12   29013                 2         1  252427           1                30
# 13   29013                 2         1  252428           1                30
# 14   29015                 2         1  252441           1                30
# 15   29015                 2         1  252442           1                30
# 16   29017                 2         1  252455           1                30
# 17   29017                 2         1  252456           1                30
# 18   29019                 2         1  252469           1                30
# 19   29019                 2         1  252470           1                30
# 20   29021                 2         1  252483           1                30
# 21   29021                 2         1  252484           1                30
# 22   29023                 2         1  252497           1                30
# 23   29023                 2         1  252498           1                30
# 24   29025                 2         1  252511           1                30
# 25   29025                 2         1  252512           1                30
# 26   29027                 2         1  252525           1                30
# 27   29027                 2         1  252526           1                30
# 28   29029                 2         1  252539           1                30
# 29   29029                 2         1  252540           1                30
# ..     ...               ...       ...     ...         ...               ...
# 200  29189                 2         1  253673           1                30
# 201  29189                 2         1  253674           1                30
# 202  29510                 2         1  253939           0                 0
# 203  29510                 2         1  253940           0                 0
# 204  29186                 2         1  253645           1                30
# 205  29186                 2         1  253646           1                30
# 206  29207                 2         1  253771           1                30
# 207  29207                 2         1  253772           1                30
# 208  29209                 2         1  253785           1                30
# 209  29209                 2         1  253786           1                30
# 210  29211                 2         1  253799           1                30
# 211  29211                 2         1  253800           1                30
# 212  29213                 2         1  253813           1                30
# 213  29213                 2         1  253814           1                30
# 214  29215                 2         1  253827           1                30
# 215  29215                 2         1  253828           1                30
# 216  29217                 2         1  253841           1                30
# 217  29217                 2         1  253842           1                30
# 218  29219                 2         1  253855           1                30
# 219  29219                 2         1  253856           1                30
# 220  29221                 2         1  253869           1                30
# 221  29221                 2         1  253870           1                30
# 222  29223                 2         1  253883           1                30
# 223  29223                 2         1  253884           1                30
# 224  29225                 2         1  253897           1                30
# 225  29225                 2         1  253898           1                30
# 226  29227                 2         1  253911           1                30
# 227  29227                 2         1  253912           1                30
# 228  29229                 2         1  253925           1                30
# 229  29229                 2         1  253926           1                30
#
#      noDataId parentGeo parentGeoAbbreviation parentGeoId  \
# 0          -1  Missouri                    MO          29
# 1          -1  Missouri                    MO          29
# 2          -1  Missouri                    MO          29
# 3          -1  Missouri                    MO          29
# 4          -1  Missouri                    MO          29
# 5          -1  Missouri                    MO          29
# 6          -1  Missouri                    MO          29
# 7          -1  Missouri                    MO          29
# 8          -1  Missouri                    MO          29
# 9          -1  Missouri                    MO          29
# 10         -1  Missouri                    MO          29
# 11         -1  Missouri                    MO          29
# 12         -1  Missouri                    MO          29
# 13         -1  Missouri                    MO          29
# 14         -1  Missouri                    MO          29
# 15         -1  Missouri                    MO          29
# 16         -1  Missouri                    MO          29
# 17         -1  Missouri                    MO          29
# 18         -1  Missouri                    MO          29
# 19         -1  Missouri                    MO          29
# 20         -1  Missouri                    MO          29
# 21         -1  Missouri                    MO          29
# 22         -1  Missouri                    MO          29
# 23         -1  Missouri                    MO          29
# 24         -1  Missouri                    MO          29
# 25         -1  Missouri                    MO          29
# 26         -1  Missouri                    MO          29
# 27         -1  Missouri                    MO          29
# 28         -1  Missouri                    MO          29
# 29         -1  Missouri                    MO          29
# ..        ...       ...                   ...         ...
# 200        -1  Missouri                    MO          29
# 201        -1  Missouri                    MO          29
# 202        -1  Missouri                    MO          29
# 203        -1  Missouri                    MO          29
# 204        -1  Missouri                    MO          29
# 205        -1  Missouri                    MO          29
# 206        -1  Missouri                    MO          29
# 207        -1  Missouri                    MO          29
# 208        -1  Missouri                    MO          29
# 209        -1  Missouri                    MO          29
# 210        -1  Missouri                    MO          29
# 211        -1  Missouri                    MO          29
# 212        -1  Missouri                    MO          29
# 213        -1  Missouri                    MO          29
# 214        -1  Missouri                    MO          29
# 215        -1  Missouri                    MO          29
# 216        -1  Missouri                    MO          29
# 217        -1  Missouri                    MO          29
# 218        -1  Missouri                    MO          29
# 219        -1  Missouri                    MO          29
# 220        -1  Missouri                    MO          29
# 221        -1  Missouri                    MO          29
# 222        -1  Missouri                    MO          29
# 223        -1  Missouri                    MO          29
# 224        -1  Missouri                    MO          29
# 225        -1  Missouri                    MO          29
# 226        -1  Missouri                    MO          29
# 227        -1  Missouri                    MO          29
# 228        -1  Missouri                    MO          29
# 229        -1  Missouri                    MO          29
#
#                       rollover stabilityFlag suppressionFlag  \
# 0     [Average: 9.1 (Modeled)]             1               0
# 1     [Average: 9.5 (Modeled)]             1               0
# 2     [Average: 9.3 (Modeled)]             1               0
# 3     [Average: 9.9 (Modeled)]             1               0
# 4     [Average: 8.9 (Modeled)]             1               0
# 5     [Average: 9.2 (Modeled)]             1               0
# 6     [Average: 9.7 (Modeled)]             1               0
# 7    [Average: 10.0 (Modeled)]             1               0
# 8     [Average: 9.5 (Modeled)]             1               0
# 9     [Average: 9.8 (Modeled)]             1               0
# 10    [Average: 9.3 (Modeled)]             1               0
# 11    [Average: 9.3 (Modeled)]             1               0
# 12    [Average: 9.3 (Modeled)]             1               0
# 13    [Average: 9.4 (Modeled)]             1               0
# 14    [Average: 9.2 (Modeled)]             1               0
# 15    [Average: 9.4 (Modeled)]             1               0
# 16    [Average: 9.7 (Modeled)]             1               0
# 17   [Average: 10.5 (Modeled)]             1               0
# 18    [Average: 9.8 (Modeled)]             1               0
# 19   [Average: 10.1 (Modeled)]             1               0
# 20    [Average: 9.6 (Modeled)]             1               0
# 21   [Average: 10.2 (Modeled)]             1               0
# 22    [Average: 9.9 (Modeled)]             1               0
# 23   [Average: 10.8 (Modeled)]             1               0
# 24    [Average: 9.2 (Modeled)]             1               0
# 25    [Average: 9.3 (Modeled)]             1               0
# 26    [Average: 9.8 (Modeled)]             1               0
# 27   [Average: 10.0 (Modeled)]             1               0
# 28    [Average: 9.4 (Modeled)]             1               0
# 29    [Average: 9.8 (Modeled)]             1               0
# ..                         ...           ...             ...
# 200  [Average: 12.0 (Modeled)]             1               0
# 201  [Average: 12.1 (Modeled)]             1               0
# 202            [Average: 11.2]             1               0
# 203            [Average: 11.5]             1               0
# 204  [Average: 10.0 (Modeled)]             1               0
# 205  [Average: 10.6 (Modeled)]             1               0
# 206  [Average: 10.3 (Modeled)]             1               0
# 207  [Average: 11.3 (Modeled)]             1               0
# 208   [Average: 9.5 (Modeled)]             1               0
# 209   [Average: 9.8 (Modeled)]             1               0
# 210   [Average: 9.0 (Modeled)]             1               0
# 211   [Average: 9.3 (Modeled)]             1               0
# 212   [Average: 9.5 (Modeled)]             1               0
# 213   [Average: 9.8 (Modeled)]             1               0
# 214   [Average: 9.1 (Modeled)]             1               0
# 215   [Average: 9.6 (Modeled)]             1               0
# 216   [Average: 9.4 (Modeled)]             1               0
# 217   [Average: 9.4 (Modeled)]             1               0
# 218  [Average: 10.2 (Modeled)]             1               0
# 219  [Average: 10.5 (Modeled)]             1               0
# 220   [Average: 9.5 (Modeled)]             1               0
# 221   [Average: 9.9 (Modeled)]             1               0
# 222   [Average: 9.4 (Modeled)]             1               0
# 223  [Average: 10.1 (Modeled)]             1               0
# 224   [Average: 9.3 (Modeled)]             1               0
# 225   [Average: 9.6 (Modeled)]             1               0
# 226   [Average: 8.7 (Modeled)]             1               0
# 227   [Average: 9.0 (Modeled)]             1               0
# 228   [Average: 9.1 (Modeled)]             1               0
# 229   [Average: 9.5 (Modeled)]             1               0
#
#                   title  year
# 0             Adair, MO  2013
# 1             Adair, MO  2014
# 2            Andrew, MO  2013
# 3            Andrew, MO  2014
# 4          Atchison, MO  2013
# 5          Atchison, MO  2014
# 6           Audrain, MO  2013
# 7           Audrain, MO  2014
# 8             Barry, MO  2013
# 9             Barry, MO  2014
# 10           Barton, MO  2013
# 11           Barton, MO  2014
# 12            Bates, MO  2013
# 13            Bates, MO  2014
# 14           Benton, MO  2013
# 15           Benton, MO  2014
# 16        Bollinger, MO  2013
# 17        Bollinger, MO  2014
# 18            Boone, MO  2013
# 19            Boone, MO  2014
# 20         Buchanan, MO  2013
# 21         Buchanan, MO  2014
# 22           Butler, MO  2013
# 23           Butler, MO  2014
# 24         Caldwell, MO  2013
# 25         Caldwell, MO  2014
# 26         Callaway, MO  2013
# 27         Callaway, MO  2014
# 28           Camden, MO  2013
# 29           Camden, MO  2014
# ..                  ...   ...
# 200       St. Louis, MO  2013
# 201       St. Louis, MO  2014
# 202  St. Louis City, MO  2013
# 203  St. Louis City, MO  2014
# 204  Ste. Genevieve, MO  2013
# 205  Ste. Genevieve, MO  2014
# 206        Stoddard, MO  2013
# 207        Stoddard, MO  2014
# 208           Stone, MO  2013
# 209           Stone, MO  2014
# 210        Sullivan, MO  2013
# 211        Sullivan, MO  2014
# 212           Taney, MO  2013
# 213           Taney, MO  2014
# 214           Texas, MO  2013
# 215           Texas, MO  2014
# 216          Vernon, MO  2013
# 217          Vernon, MO  2014
# 218          Warren, MO  2013
# 219          Warren, MO  2014
# 220      Washington, MO  2013
# 221      Washington, MO  2014
# 222           Wayne, MO  2013
# 223           Wayne, MO  2014
# 224         Webster, MO  2013
# 225         Webster, MO  2014
# 226           Worth, MO  2013
# 227           Worth, MO  2014
# 228          Wright, MO  2013
# 229          Wright, MO  2014
#
# [230 rows x 20 columns]

# %%
df = pd.DataFrame.from_dict(data['modeledTableResult'])
df
# Out:
#     calculationType dataValue displayValue             geo geoAbbreviation  \
# 0           Average       9.1          9.1           Adair           29001
# 1           Average       9.5          9.5           Adair           29001
# 2           Average       9.3          9.3          Andrew           29003
# 3           Average       9.9          9.9          Andrew           29003
# 4           Average       8.9          8.9        Atchison           29005
# 5           Average       9.2          9.2        Atchison           29005
# 6           Average       9.7          9.7         Audrain           29007
# 7           Average      10.0         10.0         Audrain           29007
# 8           Average       9.5          9.5           Barry           29009
# 9           Average       9.8          9.8           Barry           29009
# 10          Average       9.3          9.3          Barton           29011
# 11          Average       9.3          9.3          Barton           29011
# 12          Average       9.3          9.3           Bates           29013
# 13          Average       9.4          9.4           Bates           29013
# 14          Average       9.2          9.2          Benton           29015
# 15          Average       9.4          9.4          Benton           29015
# 16          Average       9.7          9.7       Bollinger           29017
# 17          Average      10.5         10.5       Bollinger           29017
# 18          Average       9.8          9.8           Boone           29019
# 19          Average      10.1         10.1           Boone           29019
# 20          Average       9.6          9.6        Buchanan           29021
# 21          Average      10.2         10.2        Buchanan           29021
# 22          Average       9.9          9.9          Butler           29023
# 23          Average      10.8         10.8          Butler           29023
# 24          Average       9.2          9.2        Caldwell           29025
# 25          Average       9.3          9.3        Caldwell           29025
# 26          Average       9.8          9.8        Callaway           29027
# 27          Average      10.0         10.0        Callaway           29027
# 28          Average       9.4          9.4          Camden           29029
# 29          Average       9.8          9.8          Camden           29029
# ..              ...       ...          ...             ...             ...
# 200         Average      12.0         12.0       St. Louis           29189
# 201         Average      12.1         12.1       St. Louis           29189
# 202         Average      11.2         11.2  St. Louis City           29510
# 203         Average      11.5         11.5  St. Louis City           29510
# 204         Average      10.0         10.0  Ste. Genevieve           29186
# 205         Average      10.6         10.6  Ste. Genevieve           29186
# 206         Average      10.3         10.3        Stoddard           29207
# 207         Average      11.3         11.3        Stoddard           29207
# 208         Average       9.5          9.5           Stone           29209
# 209         Average       9.8          9.8           Stone           29209
# 210         Average       9.0          9.0        Sullivan           29211
# 211         Average       9.3          9.3        Sullivan           29211
# 212         Average       9.5          9.5           Taney           29213
# 213         Average       9.8          9.8           Taney           29213
# 214         Average       9.1          9.1           Texas           29215
# 215         Average       9.6          9.6           Texas           29215
# 216         Average       9.4          9.4          Vernon           29217
# 217         Average       9.4          9.4          Vernon           29217
# 218         Average      10.2         10.2          Warren           29219
# 219         Average      10.5         10.5          Warren           29219
# 220         Average       9.5          9.5      Washington           29221
# 221         Average       9.9          9.9      Washington           29221
# 222         Average       9.4          9.4           Wayne           29223
# 223         Average      10.1         10.1           Wayne           29223
# 224         Average       9.3          9.3         Webster           29225
# 225         Average       9.6          9.6         Webster           29225
# 226         Average       8.7          8.7           Worth           29227
# 227         Average       9.0          9.0           Worth           29227
# 228         Average       9.1          9.1          Wright           29229
# 229         Average       9.5          9.5          Wright           29229
#
#      geoId  geographicTypeId groupById      id modeledFlag  noDataBreakGroup  \
# 0    29001                 2         1  252343           1                30
# 1    29001                 2         1  252344           1                30
# 2    29003                 2         1  252357           1                30
# 3    29003                 2         1  252358           1                30
# 4    29005                 2         1  252371           1                30
# 5    29005                 2         1  252372           1                30
# 6    29007                 2         1  252385           1                30
# 7    29007                 2         1  252386           1                30
# 8    29009                 2         1  252399           1                30
# 9    29009                 2         1  252400           1                30
# 10   29011                 2         1  252413           1                30
# 11   29011                 2         1  252414           1                30
# 12   29013                 2         1  252427           1                30
# 13   29013                 2         1  252428           1                30
# 14   29015                 2         1  252441           1                30
# 15   29015                 2         1  252442           1                30
# 16   29017                 2         1  252455           1                30
# 17   29017                 2         1  252456           1                30
# 18   29019                 2         1  252469           1                30
# 19   29019                 2         1  252470           1                30
# 20   29021                 2         1  252483           1                30
# 21   29021                 2         1  252484           1                30
# 22   29023                 2         1  252497           1                30
# 23   29023                 2         1  252498           1                30
# 24   29025                 2         1  252511           1                30
# 25   29025                 2         1  252512           1                30
# 26   29027                 2         1  252525           1                30
# 27   29027                 2         1  252526           1                30
# 28   29029                 2         1  252539           1                30
# 29   29029                 2         1  252540           1                30
# ..     ...               ...       ...     ...         ...               ...
# 200  29189                 2         1  253673           1                30
# 201  29189                 2         1  253674           1                30
# 202  29510                 2         1  253939           0                 0
# 203  29510                 2         1  253940           0                 0
# 204  29186                 2         1  253645           1                30
# 205  29186                 2         1  253646           1                30
# 206  29207                 2         1  253771           1                30
# 207  29207                 2         1  253772           1                30
# 208  29209                 2         1  253785           1                30
# 209  29209                 2         1  253786           1                30
# 210  29211                 2         1  253799           1                30
# 211  29211                 2         1  253800           1                30
# 212  29213                 2         1  253813           1                30
# 213  29213                 2         1  253814           1                30
# 214  29215                 2         1  253827           1                30
# 215  29215                 2         1  253828           1                30
# 216  29217                 2         1  253841           1                30
# 217  29217                 2         1  253842           1                30
# 218  29219                 2         1  253855           1                30
# 219  29219                 2         1  253856           1                30
# 220  29221                 2         1  253869           1                30
# 221  29221                 2         1  253870           1                30
# 222  29223                 2         1  253883           1                30
# 223  29223                 2         1  253884           1                30
# 224  29225                 2         1  253897           1                30
# 225  29225                 2         1  253898           1                30
# 226  29227                 2         1  253911           1                30
# 227  29227                 2         1  253912           1                30
# 228  29229                 2         1  253925           1                30
# 229  29229                 2         1  253926           1                30
#
#      noDataId parentGeo parentGeoAbbreviation parentGeoId  \
# 0          -1  Missouri                    MO          29
# 1          -1  Missouri                    MO          29
# 2          -1  Missouri                    MO          29
# 3          -1  Missouri                    MO          29
# 4          -1  Missouri                    MO          29
# 5          -1  Missouri                    MO          29
# 6          -1  Missouri                    MO          29
# 7          -1  Missouri                    MO          29
# 8          -1  Missouri                    MO          29
# 9          -1  Missouri                    MO          29
# 10         -1  Missouri                    MO          29
# 11         -1  Missouri                    MO          29
# 12         -1  Missouri                    MO          29
# 13         -1  Missouri                    MO          29
# 14         -1  Missouri                    MO          29
# 15         -1  Missouri                    MO          29
# 16         -1  Missouri                    MO          29
# 17         -1  Missouri                    MO          29
# 18         -1  Missouri                    MO          29
# 19         -1  Missouri                    MO          29
# 20         -1  Missouri                    MO          29
# 21         -1  Missouri                    MO          29
# 22         -1  Missouri                    MO          29
# 23         -1  Missouri                    MO          29
# 24         -1  Missouri                    MO          29
# 25         -1  Missouri                    MO          29
# 26         -1  Missouri                    MO          29
# 27         -1  Missouri                    MO          29
# 28         -1  Missouri                    MO          29
# 29         -1  Missouri                    MO          29
# ..        ...       ...                   ...         ...
# 200        -1  Missouri                    MO          29
# 201        -1  Missouri                    MO          29
# 202        -1  Missouri                    MO          29
# 203        -1  Missouri                    MO          29
# 204        -1  Missouri                    MO          29
# 205        -1  Missouri                    MO          29
# 206        -1  Missouri                    MO          29
# 207        -1  Missouri                    MO          29
# 208        -1  Missouri                    MO          29
# 209        -1  Missouri                    MO          29
# 210        -1  Missouri                    MO          29
# 211        -1  Missouri                    MO          29
# 212        -1  Missouri                    MO          29
# 213        -1  Missouri                    MO          29
# 214        -1  Missouri                    MO          29
# 215        -1  Missouri                    MO          29
# 216        -1  Missouri                    MO          29
# 217        -1  Missouri                    MO          29
# 218        -1  Missouri                    MO          29
# 219        -1  Missouri                    MO          29
# 220        -1  Missouri                    MO          29
# 221        -1  Missouri                    MO          29
# 222        -1  Missouri                    MO          29
# 223        -1  Missouri                    MO          29
# 224        -1  Missouri                    MO          29
# 225        -1  Missouri                    MO          29
# 226        -1  Missouri                    MO          29
# 227        -1  Missouri                    MO          29
# 228        -1  Missouri                    MO          29
# 229        -1  Missouri                    MO          29
#
#                       rollover stabilityFlag suppressionFlag  \
# 0     [Average: 9.1 (Modeled)]             1               0
# 1     [Average: 9.5 (Modeled)]             1               0
# 2     [Average: 9.3 (Modeled)]             1               0
# 3     [Average: 9.9 (Modeled)]             1               0
# 4     [Average: 8.9 (Modeled)]             1               0
# 5     [Average: 9.2 (Modeled)]             1               0
# 6     [Average: 9.7 (Modeled)]             1               0
# 7    [Average: 10.0 (Modeled)]             1               0
# 8     [Average: 9.5 (Modeled)]             1               0
# 9     [Average: 9.8 (Modeled)]             1               0
# 10    [Average: 9.3 (Modeled)]             1               0
# 11    [Average: 9.3 (Modeled)]             1               0
# 12    [Average: 9.3 (Modeled)]             1               0
# 13    [Average: 9.4 (Modeled)]             1               0
# 14    [Average: 9.2 (Modeled)]             1               0
# 15    [Average: 9.4 (Modeled)]             1               0
# 16    [Average: 9.7 (Modeled)]             1               0
# 17   [Average: 10.5 (Modeled)]             1               0
# 18    [Average: 9.8 (Modeled)]             1               0
# 19   [Average: 10.1 (Modeled)]             1               0
# 20    [Average: 9.6 (Modeled)]             1               0
# 21   [Average: 10.2 (Modeled)]             1               0
# 22    [Average: 9.9 (Modeled)]             1               0
# 23   [Average: 10.8 (Modeled)]             1               0
# 24    [Average: 9.2 (Modeled)]             1               0
# 25    [Average: 9.3 (Modeled)]             1               0
# 26    [Average: 9.8 (Modeled)]             1               0
# 27   [Average: 10.0 (Modeled)]             1               0
# 28    [Average: 9.4 (Modeled)]             1               0
# 29    [Average: 9.8 (Modeled)]             1               0
# ..                         ...           ...             ...
# 200  [Average: 12.0 (Modeled)]             1               0
# 201  [Average: 12.1 (Modeled)]             1               0
# 202            [Average: 11.2]             1               0
# 203            [Average: 11.5]             1               0
# 204  [Average: 10.0 (Modeled)]             1               0
# 205  [Average: 10.6 (Modeled)]             1               0
# 206  [Average: 10.3 (Modeled)]             1               0
# 207  [Average: 11.3 (Modeled)]             1               0
# 208   [Average: 9.5 (Modeled)]             1               0
# 209   [Average: 9.8 (Modeled)]             1               0
# 210   [Average: 9.0 (Modeled)]             1               0
# 211   [Average: 9.3 (Modeled)]             1               0
# 212   [Average: 9.5 (Modeled)]             1               0
# 213   [Average: 9.8 (Modeled)]             1               0
# 214   [Average: 9.1 (Modeled)]             1               0
# 215   [Average: 9.6 (Modeled)]             1               0
# 216   [Average: 9.4 (Modeled)]             1               0
# 217   [Average: 9.4 (Modeled)]             1               0
# 218  [Average: 10.2 (Modeled)]             1               0
# 219  [Average: 10.5 (Modeled)]             1               0
# 220   [Average: 9.5 (Modeled)]             1               0
# 221   [Average: 9.9 (Modeled)]             1               0
# 222   [Average: 9.4 (Modeled)]             1               0
# 223  [Average: 10.1 (Modeled)]             1               0
# 224   [Average: 9.3 (Modeled)]             1               0
# 225   [Average: 9.6 (Modeled)]             1               0
# 226   [Average: 8.7 (Modeled)]             1               0
# 227   [Average: 9.0 (Modeled)]             1               0
# 228   [Average: 9.1 (Modeled)]             1               0
# 229   [Average: 9.5 (Modeled)]             1               0
#
#                   title  year
# 0             Adair, MO  2013
# 1             Adair, MO  2014
# 2            Andrew, MO  2013
# 3            Andrew, MO  2014
# 4          Atchison, MO  2013
# 5          Atchison, MO  2014
# 6           Audrain, MO  2013
# 7           Audrain, MO  2014
# 8             Barry, MO  2013
# 9             Barry, MO  2014
# 10           Barton, MO  2013
# 11           Barton, MO  2014
# 12            Bates, MO  2013
# 13            Bates, MO  2014
# 14           Benton, MO  2013
# 15           Benton, MO  2014
# 16        Bollinger, MO  2013
# 17        Bollinger, MO  2014
# 18            Boone, MO  2013
# 19            Boone, MO  2014
# 20         Buchanan, MO  2013
# 21         Buchanan, MO  2014
# 22           Butler, MO  2013
# 23           Butler, MO  2014
# 24         Caldwell, MO  2013
# 25         Caldwell, MO  2014
# 26         Callaway, MO  2013
# 27         Callaway, MO  2014
# 28           Camden, MO  2013
# 29           Camden, MO  2014
# ..                  ...   ...
# 200       St. Louis, MO  2013
# 201       St. Louis, MO  2014
# 202  St. Louis City, MO  2013
# 203  St. Louis City, MO  2014
# 204  Ste. Genevieve, MO  2013
# 205  Ste. Genevieve, MO  2014
# 206        Stoddard, MO  2013
# 207        Stoddard, MO  2014
# 208           Stone, MO  2013
# 209           Stone, MO  2014
# 210        Sullivan, MO  2013
# 211        Sullivan, MO  2014
# 212           Taney, MO  2013
# 213           Taney, MO  2014
# 214           Texas, MO  2013
# 215           Texas, MO  2014
# 216          Vernon, MO  2013
# 217          Vernon, MO  2014
# 218          Warren, MO  2013
# 219          Warren, MO  2014
# 220      Washington, MO  2013
# 221      Washington, MO  2014
# 222           Wayne, MO  2013
# 223           Wayne, MO  2014
# 224         Webster, MO  2013
# 225         Webster, MO  2014
# 226           Worth, MO  2013
# 227           Worth, MO  2014
# 228          Wright, MO  2013
# 229          Wright, MO  2014
#
# [230 rows x 20 columns]

# %%
df.loc[df['geo']=='St. Louis']
# Out:
#     calculationType dataValue displayValue        geo geoAbbreviation  geoId  \
# 200         Average      12.0         12.0  St. Louis           29189  29189
# 201         Average      12.1         12.1  St. Louis           29189  29189
#
#      geographicTypeId groupById      id modeledFlag  noDataBreakGroup  \
# 200                 2         1  253673           1                30
# 201                 2         1  253674           1                30
#
#      noDataId parentGeo parentGeoAbbreviation parentGeoId  \
# 200        -1  Missouri                    MO          29
# 201        -1  Missouri                    MO          29
#
#                       rollover stabilityFlag suppressionFlag          title  \
# 200  [Average: 12.0 (Modeled)]             1               0  St. Louis, MO
# 201  [Average: 12.1 (Modeled)]             1               0  St. Louis, MO
#
#      year
# 200  2013
# 201  2014

# %%
stl2014 = df.loc[(df['geo']=='St. Louis') & (df['year']=='2014')] 
print(json.dumps(stl2014.to_dict(),indent=4))
# Out:
# {
#     "title": {
#         "201": "St. Louis, MO"
#     },
#     "calculationType": {
#         "201": "Average"
#     },
#     "geographicTypeId": {
#         "201": 2
#     },
#     "id": {
#         "201": "253674"
#     },
#     "year": {
#         "201": "2014"
#     },
#     "parentGeoId": {
#         "201": "29"
#     },
#     "displayValue": {
#         "201": "12.1"
#     },
#     "parentGeo": {
#         "201": "Missouri"
#     },
#     "rollover": {
#         "201": [
#             "Average: 12.1 (Modeled)"
#         ]
#     },
#     "dataValue": {
#         "201": "12.1"
#     },
#     "groupById": {
#         "201": "1"
#     },
#     "suppressionFlag": {
#         "201": "0"
#     },
#     "geoAbbreviation": {
#         "201": "29189"
#     },
#     "geoId": {
#         "201": "29189"
#     },
#     "geo": {
#         "201": "St. Louis"
#     },
#     "noDataBreakGroup": {
#         "201": 30
#     },
#     "modeledFlag": {
#         "201": "1"
#     },
#     "parentGeoAbbreviation": {
#         "201": "MO"
#     },
#     "noDataId": {
#         "201": -1
#     },
#     "stabilityFlag": {
#         "201": "1"
#     }
# }

# %% [markdown]
# Base64 Decode Photo
# ===

# %%
with open('/data/patient-example-a.json') as patfile:
    pat = json.load(patfile)

# %%
imgtext = pat['photo'][0]['data']
imgtext
# Out:
# '...'

# %%
import base64
img = base64.b64decode(imgtext)

# %%
with open ('photo.gif','wb') as imgfile:
    imgfile.write(img)

# %% [markdown]
# ![title](photo.gif)
